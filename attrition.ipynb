# %% [markdown]
# ## Part 1: Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras import layers

#  Import and read the attrition data
attrition_df = pd.read_csv('https://static.bc-edx.com/ai/ail-v-1-0/m19/lms/datasets/attrition.csv')
attrition_df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  HourlyRate  \
# 0          2  Life Sciences                        2          94
# 1          1  Life Sciences                        3          61
# 2          2          Other                        4          92
# 3          4  Life Sciences                        4          56
# 4          1        Medical                        1          40
#
#    JobInvolvement  ...  PerformanceRating RelationshipSatisfaction  \
# 0               3  ...                  3                        1
# 1               2  ...                  4                        4
# 2               2  ...                  3                        2
# 3               3  ...                  3                        3
# 4               3  ...                  3                        4
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                 8                      0               1
# 1                 1                10                      3               3
# 2                 0                 7                      3               3
# 3                 0                 8                      3               3
# 4                 1                 6                      3               3
#
#    YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                   4                        0
# 1              10                   7                        1
# 2               0                   0                        0
# 3               8                   7                        3
# 4               2                   2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 27 columns]

# %%
# Determine the number of unique values in each column.
attrition_df.nunique()
# Out:
# Age                         43
# Attrition                    2
# BusinessTravel               3
# Department                   3
# DistanceFromHome            29
# Education                    5
# EducationField               6
# EnvironmentSatisfaction      4
# HourlyRate                  71
# JobInvolvement               4
# JobLevel                     5
# JobRole                      9
# JobSatisfaction              4
# MaritalStatus                3
# NumCompaniesWorked          10
# OverTime                     2
# PercentSalaryHike           15
# PerformanceRating            2
# RelationshipSatisfaction     4
# StockOptionLevel             4
# TotalWorkingYears           40
# TrainingTimesLastYear        7
# WorkLifeBalance              4
# YearsAtCompany              37
# YearsInCurrentRole          19
# YearsSinceLastPromotion     16
# YearsWithCurrManager        18
# dtype: int64

# %% [markdown]
# ### Review of data types in df

# %%
for column in attrition_df.columns:
  if type(attrition_df[column][0])==str:
    print('*'*5,column,'*'*5)
    print(attrition_df[column].value_counts())
    print()
# Out:
# ***** Attrition *****
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
#
# ***** BusinessTravel *****
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
#
# ***** Department *****
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
#
# ***** EducationField *****
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
#
# ***** JobRole *****
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64
#
# ***** MaritalStatus *****
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64
#
# ***** OverTime *****
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %%
attrition_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   Department                1470 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   Education                 1470 non-null   int64
#  6   EducationField            1470 non-null   object
#  7   EnvironmentSatisfaction   1470 non-null   int64
#  8   HourlyRate                1470 non-null   int64
#  9   JobInvolvement            1470 non-null   int64
#  10  JobLevel                  1470 non-null   int64
#  11  JobRole                   1470 non-null   object
#  12  JobSatisfaction           1470 non-null   int64
#  13  MaritalStatus             1470 non-null   object
#  14  NumCompaniesWorked        1470 non-null   int64
#  15  OverTime                  1470 non-null   object
#  16  PercentSalaryHike         1470 non-null   int64
#  17  PerformanceRating         1470 non-null   int64
#  18  RelationshipSatisfaction  1470 non-null   int64
#  19  StockOptionLevel          1470 non-null   int64
#  20  TotalWorkingYears         1470 non-null   int64
#  21  TrainingTimesLastYear     1470 non-null   int64
#  22  WorkLifeBalance           1470 non-null   int64
#  23  YearsAtCompany            1470 non-null   int64
#  24  YearsInCurrentRole        1470 non-null   int64
#  25  YearsSinceLastPromotion   1470 non-null   int64
#  26  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(20), object(7)
# memory usage: 310.2+ KB

# %% [markdown]
# ### Back to Original Instruction Cells

# %%
# Create y_df with the Attrition and Department columns
y_df=attrition_df[['Attrition','Department']]
y_df
# Out:
#      Attrition              Department
# 0          Yes                   Sales
# 1           No  Research & Development
# 2          Yes  Research & Development
# 3           No  Research & Development
# 4           No  Research & Development
# ...        ...                     ...
# 1465        No  Research & Development
# 1466        No  Research & Development
# 1467        No  Research & Development
# 1468        No                   Sales
# 1469        No  Research & Development
#
# [1470 rows x 2 columns]

# %%
attrition_df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# Create a list of at least 10 column names to use as X data
X=attrition_df.drop(columns=['Attrition','Department'])


# Create X_df using your selected columns
X_df=pd.DataFrame(X)

# Show the data types for X_df
X_df.dtypes
# Out:
# Age                          int64
# BusinessTravel              object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EnvironmentSatisfaction      int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# NumCompaniesWorked           int64
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# ### Lazy_Encoder

# %%
def lazy_Encoder(df):
  from sklearn.preprocessing import OneHotEncoder
  ohe=OneHotEncoder(handle_unknown='ignore', sparse_output=False).set_output(transform='pandas')
  for column in df.columns:
    if df[column].dtype=='O':
      if len(df[column].value_counts())==2:
        new_cols=pd.get_dummies(df[column], dtype=int, drop_first=True)
        df[column]=new_cols
      else :
        new_cols=ohe.fit_transform(df[[column]])
        df=pd.concat([df,new_cols], axis=1).drop(columns=[column])
  return df

# %% [markdown]
# ### Back to Original Instruction Cells

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_attrition_train, y_attrition_test, y_department_train, y_department_test\
 =train_test_split(X_df,y_df['Attrition'],y_df['Department'],random_state=42)

# %%
y_department_train
# Out:
# 1343    Research & Development
# 1121                     Sales
# 1048                     Sales
# 1393                     Sales
# 527                      Sales
#                  ...
# 1130    Research & Development
# 1294    Research & Development
# 860     Research & Development
# 1459    Research & Development
# 1126                     Sales
# Name: Department, Length: 1102, dtype: object

# %%
# Convert your X data to numeric data types however you see fit
# Add new code cells as necessary
X_train_enc=lazy_Encoder(X_train)
X_test_enc=lazy_Encoder(X_test)

# %%
# Create a StandardScaler
ss_model=StandardScaler()

# Fit the StandardScaler to the training data
ss_model.fit(X_train_enc)

# Scale the training and testing data
X_train_scaled_df=pd.DataFrame(ss_model.transform(X_train_enc))
X_test_scaled_df=pd.DataFrame(ss_model.transform(X_test_enc))

# %%
y_department_train
# Out:
# 1343    Research & Development
# 1121                     Sales
# 1048                     Sales
# 1393                     Sales
# 527                      Sales
#                  ...
# 1130    Research & Development
# 1294    Research & Development
# 860     Research & Development
# 1459    Research & Development
# 1126                     Sales
# Name: Department, Length: 1102, dtype: object

# %%
# Create a OneHotEncoder for the Department column
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder(sparse_output=False)

# Fit the encoder to the training data
ohe.fit(np.array(y_department_train).reshape(-1,1))


# Create two new variables by applying the encoder
# to the training and testing data
y_Department_train_enc=ohe.transform(np.array(y_department_train).reshape(-1,1))
y_Department_test_enc=ohe.transform(np.array(y_department_test).reshape(-1,1))

# %%
# Create a OneHotEncoder for the Attrition column
ohe=OneHotEncoder(sparse_output=False)


# Fit the encoder to the training data
ohe.fit(np.array(y_attrition_train).reshape(-1,1))

# Create two new variables by applying the encoder
# to the training and testing data
y_Attrition_train_enc=ohe.transform(np.array(y_attrition_train).reshape(-1,1))
y_Attrition_test_enc=ohe.transform(np.array(y_attrition_test).reshape(-1,1))

# %% [markdown]
# ## Create, Compile, and Train the Model

# %%
# Find the number of columns in the X training data
input_nodes=len(X_train_scaled_df.columns)

# Create the input layer
input_layer= layers.Input(shape=input_nodes,name='input_features')

# Create at least two shared layers
shared_layer1=layers.Dense(64,activation='relu', name='shared_layer1')(input_layer)
shared_layer2=layers.Dense(32,activation='relu', name='shared_layer2')(shared_layer1)

# %%
# Create a branch for Department
# with a hidden layer and an output layer

# Create the hidden layer
shared_layer3=layers.Dense(64,activation='relu',name='shared_layer3')(shared_layer2)
shared_layer5=layers.Dense(32,activation='relu',name='shared_layer5')(shared_layer3)

# Create the output layer
Department_output = layers.Dense(3,activation='sigmoid',name='Department_output')(shared_layer5)

# %%
# Create a branch for Attrition
# with a hidden layer and an output layer

# Create the hidden layer
shared_layer4=layers.Dense(32,activation='relu',name='shared_layer4')(shared_layer2)

# Create the output layer
Attrition_output = layers.Dense(2,activation='sigmoid',name='Attrition_output')(shared_layer4)

# %%
# Create the model
model=Model(inputs=input_layer,outputs=[Department_output, Attrition_output])

# Compile the model
model.compile(optimizer='adam',
              loss={'Department_output':'binary_crossentropy',
                    'Attrition_output':'binary_crossentropy'},
              metrics= {'Department_output':'accuracy',
                    'Attrition_output':'accuracy'},
              )

# Summarize the model
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_features (InputLayer  [(None, 42)]                 0         []
#  )
#
#  shared_layer1 (Dense)       (None, 64)                   2752      ['input_features[0][0]']
#
#  shared_layer2 (Dense)       (None, 32)                   2080      ['shared_layer1[0][0]']
#
#  shared_layer3 (Dense)       (None, 64)                   2112      ['shared_layer2[0][0]']
#
#  shared_layer5 (Dense)       (None, 32)                   2080      ['shared_layer3[0][0]']
#
#  shared_layer4 (Dense)       (None, 32)                   1056      ['shared_layer2[0][0]']
#
#  Department_output (Dense)   (None, 3)                    99        ['shared_layer5[0][0]']
#
#  Attrition_output (Dense)    (None, 2)                    66        ['shared_layer4[0][0]']
#
# ==================================================================================================
# Total params: 10245 (40.02 KB)
# Trainable params: 10245 (40.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Train the model
model.fit(X_train_scaled_df,
          {'Department_output': y_Department_train_enc,
           'Attrition_output': y_Attrition_train_enc},
          epochs=10,
          batch_size=32,
          validation_split=0.2
          )
# Out:
# Epoch 1/10
# 28/28 [==============================] - 2s 25ms/step - loss: 0.7130 - Department_output_loss: 0.4850 - Attrition_output_loss: 0.2281 - Department_output_accuracy: 0.6425 - Attrition_output_accuracy: 0.9092 - val_loss: 0.7500 - val_Department_output_loss: 0.3319 - val_Attrition_output_loss: 0.4181 - val_Department_output_accuracy: 0.8190 - val_Attrition_output_accuracy: 0.8054
# Epoch 2/10
# 28/28 [==============================] - 0s 10ms/step - loss: 0.4097 - Department_output_loss: 0.1957 - Attrition_output_loss: 0.2140 - Department_output_accuracy: 0.9251 - Attrition_output_accuracy: 0.9183 - val_loss: 0.5644 - val_Department_output_loss: 0.1256 - val_Attrition_output_loss: 0.4388 - val_Department_output_accuracy: 0.9548 - val_Attrition_output_accuracy: 0.8100
# Epoch 3/10
# 28/28 [==============================] - 0s 9ms/step - loss: 0.2630 - Department_output_loss: 0.0605 - Attrition_output_loss: 0.2026 - Department_output_accuracy: 0.9773 - Attrition_output_accuracy: 0.9194 - val_loss: 0.5232 - val_Department_output_loss: 0.0826 - val_Attrition_output_loss: 0.4405 - val_Department_output_accuracy: 0.9367 - val_Attrition_output_accuracy: 0.8235
# Epoch 4/10
# 28/28 [==============================] - 0s 8ms/step - loss: 0.2203 - Department_output_loss: 0.0311 - Attrition_output_loss: 0.1892 - Department_output_accuracy: 0.9898 - Attrition_output_accuracy: 0.9251 - val_loss: 0.5251 - val_Department_output_loss: 0.0772 - val_Attrition_output_loss: 0.4480 - val_Department_output_accuracy: 0.9502 - val_Attrition_output_accuracy: 0.8009
# Epoch 5/10
# 28/28 [==============================] - 0s 8ms/step - loss: 0.2005 - Department_output_loss: 0.0215 - Attrition_output_loss: 0.1790 - Department_output_accuracy: 0.9921 - Attrition_output_accuracy: 0.9387 - val_loss: 0.5438 - val_Department_output_loss: 0.0891 - val_Attrition_output_loss: 0.4546 - val_Department_output_accuracy: 0.9412 - val_Attrition_output_accuracy: 0.8054
# Epoch 6/10
# 28/28 [==============================] - 0s 9ms/step - loss: 0.1848 - Department_output_loss: 0.0164 - Attrition_output_loss: 0.1683 - Department_output_accuracy: 0.9955 - Attrition_output_accuracy: 0.9376 - val_loss: 0.5561 - val_Department_output_loss: 0.0882 - val_Attrition_output_loss: 0.4679 - val_Department_output_accuracy: 0.9457 - val_Attrition_output_accuracy: 0.8054
# Epoch 7/10
# 28/28 [==============================] - 0s 9ms/step - loss: 0.1697 - Department_output_loss: 0.0133 - Attrition_output_loss: 0.1564 - Department_output_accuracy: 0.9943 - Attrition_output_accuracy: 0.9410 - val_loss: 0.5772 - val_Department_output_loss: 0.0931 - val_Attrition_output_loss: 0.4841 - val_Department_output_accuracy: 0.9457 - val_Attrition_output_accuracy: 0.8054
# Epoch 8/10
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1535 - Department_output_loss: 0.0107 - Attrition_output_loss: 0.1428 - Department_output_accuracy: 0.9955 - Attrition_output_accuracy: 0.9546 - val_loss: 0.5691 - val_Department_output_loss: 0.0790 - val_Attrition_output_loss: 0.4901 - val_Department_output_accuracy: 0.9412 - val_Attrition_output_accuracy: 0.8054
# Epoch 9/10
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1408 - Department_output_loss: 0.0092 - Attrition_output_loss: 0.1316 - Department_output_accuracy: 0.9966 - Attrition_output_accuracy: 0.9580 - val_loss: 0.6051 - val_Department_output_loss: 0.1083 - val_Attrition_output_loss: 0.4967 - val_Department_output_accuracy: 0.9457 - val_Attrition_output_accuracy: 0.8100
# Epoch 10/10
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1307 - Department_output_loss: 0.0076 - Attrition_output_loss: 0.1231 - Department_output_accuracy: 0.9977 - Attrition_output_accuracy: 0.9648 - val_loss: 0.6129 - val_Department_output_loss: 0.0948 - val_Attrition_output_loss: 0.5181 - val_Department_output_accuracy: 0.9457 - val_Attrition_output_accuracy: 0.8009

# %%
# Evaluate the model with the testing data
test_results=model.evaluate(X_test_enc,
 {'Department_output': y_Department_test_enc, 'Attrition_output': y_Attrition_test_enc})
test_results
# Out:
# 12/12 [==============================] - 0s 3ms/step - loss: 6.8986 - Department_output_loss: 3.1081 - Attrition_output_loss: 3.7905 - Department_output_accuracy: 0.6359 - Attrition_output_accuracy: 0.8696
# [6.898604869842529,
#  3.1080658435821533,
#  3.790539264678955,
#  0.635869562625885,
#  0.8695651888847351]

# %%
# Print the accuracy for both department and attrition
print(f"Department Accuracy : {test_results[-2]}")
print(f"Attrition Accuracy : {test_results[-1]}")
# Out:
# Department Accuracy : 0.635869562625885
# Attrition Accuracy : 0.8695651888847351

# %% [markdown]
# # Summary
#
# In the provided space below, briefly answer the following questions.
#
# 1. Is accuracy the best metric to use on this data? Why or why not?
#
# 2. What activation functions did you choose for your output layers, and why?
#
# 3. Can you name a few ways that this model might be improved?

# %% [markdown]
# YOUR ANSWERS HERE
#
# 1. **Yes**, because we are looking for a match or no match result
# 2. **sigmoid**, the results to compare to are 0 and 1, sigmoid gives 0 to 1 results that get rounded to 0 or 1
# 3. Add more layers and/or mode nodes to the result with the lowest accuracy
